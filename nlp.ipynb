# %%
Text Analytics
1. Extract Sample document and apply following document preprocessing methods:
Tokenization, POS Tagging, stop words removal, Stemming and Lemmatization.
2. Create representation of document by calculating Term Frequency and Inverse Document 
Frequency

# %%
# Import libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Download NLTK data (run only once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\amana\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Sample document
text = "Text analytics helps to find useful information from text data."

# %%
# 1. Tokenization
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['Text', 'analytics', 'helps', 'to', 'find', 'useful', 'information', 'from', 'text', 'data', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# 2. POS Tagging
tags = pos_tag(tokens)
print("POS Tags:", tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\amana\AppData\Roaming\nltk_data...
# POS Tags: [('Text', 'NN'), ('analytics', 'NNS'), ('helps', 'VBZ'), ('to', 'TO'), ('find', 'VB'), ('useful', 'JJ'), ('information', 'NN'), ('from', 'IN'), ('text', 'NN'), ('data', 'NNS'), ('.', '.')]
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.

# %%
# 3. Stop Words Removal
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("After Stop Word Removal:", filtered_tokens)
# Out:
# After Stop Word Removal: ['Text', 'analytics', 'helps', 'find', 'useful', 'information', 'text', 'data', '.']

# %%
# 4. Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered_tokens]
print("After Stemming:", stemmed)
# Out:
# After Stemming: ['text', 'analyt', 'help', 'find', 'use', 'inform', 'text', 'data', '.']

# %%
# 5. Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("After Lemmatization:", lemmatized)
# Out:
# After Lemmatization: ['Text', 'analytics', 'help', 'find', 'useful', 'information', 'text', 'data', '.']

# %%
# 6. TF-IDF Representation using two small documents
documents = [
    "Text analytics finds data from text.",
    "Analytics helps in understanding text data."
]

# %%
# Create TF-IDF matrix
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(documents)

# %%
# Show TF-IDF result
print("\nTF-IDF Terms:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n", tfidf.toarray())
# Out:
# TF-IDF Terms: ['analytics' 'data' 'finds' 'from' 'helps' 'in' 'text' 'understanding']
# TF-IDF Matrix:
#  [[0.31701073 0.31701073 0.44554752 0.44554752 0.         0.
#   0.63402146 0.        ]
#  [0.33471228 0.33471228 0.         0.         0.47042643 0.47042643
#   0.33471228 0.47042643]]
